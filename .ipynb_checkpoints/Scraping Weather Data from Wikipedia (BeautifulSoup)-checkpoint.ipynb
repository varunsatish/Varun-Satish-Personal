# %%
import pandas as pd
import urllib
from bs4 import BeautifulSoup
import lxml

# %%
link = "https://en.wikipedia.org/wiki/List_of_countries_by_greenhouse_gas_emissions"
page = urllib.request.urlopen(link).read().decode('utf-8')
soup = BeautifulSoup(page, "html.parser")

# %%
table_classes = {"class": ["sortable", "plainrowheaders"]}
table = soup.find("table", table_classes)

# %%
#statistics
#this is iterating through every row, extracting columns and then appending them to our list
#since the column values themselves are not well defined, we are using their length to define them

GHG = []
percentage = []

for row in table.findAll("tr"):
    cells = row.findAll("td")
    #For each "tr", assign each "td" to a variable.
    if len(cells) == 3:
        GHG.append(cells[1].text)
        percentage.append(cells[2].find(text=True))

# %%
#countries
country_raw = []

for a in soup.findAll('a', title = True):
    country_raw.append(a['title'])

# %%
#countries pick up extra elements, trying to just use the countries

upper_bound = country_raw.index("China")
lower_bound = country_raw.index("Nauru") + 1

# %%
country = country_raw[0 + upper_bound:lower_bound]
country.insert(0, "World")

# %%
Greenhouse = pd.DataFrame(country)
Greenhouse['Percentage of Global Total'] = pd.DataFrame(percentage)
Greenhouse['GHG Emissions'] = pd.DataFrame(GHG)
Greenhouse = Greenhouse.rename(columns = {0:'Country'})

# %%
#Greenhouse.to_csv('Greenhouse.csv', sep = ',')
Greenhouse
# Out:
#                               Country Percentage of Global Total GHG Emissions
# 0                               World                   100.00%
#     45261.2517
# 1                               China                     25.9%
#      12454.711
# 2                       United States                    14.75%
#      6673.4497
# 3                      European Union                     9.33%
#      4224.5217
# 4                      European Union                     7.45%
#      3374.0348
# 5                               India                     6.43%
#      2379.1668
# 6                              Russia                     4.86%
#      2199.1173
# 7                               Japan                     2.99%
#      1353.3473
# 8                              Brazil                     2.25%
#      1017.8745
# 9                             Germany                     1.98%
#       894.0570
# 10                          Indonesia                     1.64%
#       744.3403
# 11                             Canada                     1.63%
#       738.3825
# 12                             Mexico                     1.62%
#       733.0104
# 13                               Iran                     1.58%
#       716.8149
# 14                        South Korea                     1.49%
#       673.5412
# 15                          Australia                     1.28%
#       580.0997
# 16                       Saudi Arabia                     1.21%
#       546.8181
# 17                     United Kingdom                     1.21%
#       546.2641
# 18                       South Africa                     1.13%
#       510.2377
# 19                             France                     0.97%
#       440.8485
# 20                              Italy                     0.93%
#       420.8244
# 21                             Turkey                     0.90%
#       408.4574
# 22                            Ukraine                     0.83%
#       375.6670
# 23                           Thailand                     0.82%
#       369.4310
# 24                             Poland                     0.80%
#       361.1905
# 25                          Argentina                     0.74%
#       334.2374
# 26                           Pakistan                     0.72%
#       326.7740
# 27                         Kazakhstan                     0.69%
#       313.7248
# 28                              Spain                     0.68%
#       306.6117
# 29                            Nigeria                     0.67%
#       304.0637
# ..                                ...                        ...           ...
# 157                          Suriname                     0.01%
#         3.3542
# 158                           Burundi                     0.01%
#         3.0465
# 159                             Malta                     0.01%
#         2.9785
# 160                           Iceland                     0.01%
#         2.9290
# 161                         Swaziland                     0.01%
#         2.8598
# 162                              Fiji                     0.01%
#         2.7564
# 163                           Liberia                     0.00%
#         2.1519
# 164                           Grenada                     0.00%
#         2.0022
# 165                     Guinea-Bissau                     0.00%
#         1.9723
# 166                            Bhutan                     0.00%
#         1.4583
# 167                          Djibouti                     0.00%
#         1.3934
# 168                          Maldives                     0.00%
#         1.1360
# 169                       Saint Lucia                     0.00%
#         1.1330
# 170               Antigua and Barbuda                     0.00%
#         1.0993
# 171                        Seychelles                     0.00%
#         0.7113
# 172                           Vanuatu                     0.00%
#         0.6735
# 173                        Cape Verde                     0.00%
#         0.6000
# 174                   Solomon Islands                     0.00%
#         0.5595
# 175                             Samoa                     0.00%
#         0.5099
# 176             Saint Kitts and Nevis                     0.00%
#         0.4262
# 177                             Tonga                     0.00%
#         0.4116
# 178                           Comoros                     0.00%
#         0.4038
# 179                             Palau                     0.00%
#         0.3576
# 180  Saint Vincent and the Grenadines                     0.00%
#         0.2753
# 181                          Dominica                     0.00%
#         0.2399
# 182             São Tomé and Príncipe                     0.00%
#         0.1887
# 183                      Cook Islands                     0.00%
#         0.1092
# 184                              Niue                     0.00%
#         0.0912
# 185                          Kiribati                     0.00%
#         0.0844
# 186                             Nauru                     0.00%
#         0.0498
#
# [187 rows x 3 columns]

# %%
# Out:
# 187
